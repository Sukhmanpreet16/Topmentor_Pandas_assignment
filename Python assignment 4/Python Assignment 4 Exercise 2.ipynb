# %%
import pandas as pd

# %%
chipo= pd.read_csv("D:/Data science assignments/Python assignment 4/File/chipotle_Ex2.csv")

# %%
chipo.head(10)
# Out:
#    Unnamed: 0  order_id  quantity                              item_name  \
# 0           0         1         1           Chips and Fresh Tomato Salsa
# 1           1         1         1                                   Izze
# 2           2         1         1                       Nantucket Nectar
# 3           3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4           4         2         2                           Chicken Bowl
# 5           5         3         1                           Chicken Bowl
# 6           6         3         1                          Side of Chips
# 7           7         4         1                          Steak Burrito
# 8           8         4         1                       Steak Soft Tacos
# 9           9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
chipo.shape
# Out:
# (4622, 6)

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
len(chipo.columns)
# Out:
# 6

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
chipo.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
chipo["item_name"].value_counts().idxmax()
# Out:
# 'Chicken Bowl'

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
chipo[chipo["item_name"]==chipo["item_name"].value_counts().idxmax()]["quantity"].sum()
# Out:
# 761

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
chipo["choice_description"].value_counts().head(1)
# Out:
# choice_description
# [Diet Coke]    134
# Name: count, dtype: int64

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %%
chipo["item_name"].count()
# Out:
# 4622

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
chipo["item_price"].dtype
# Out:
# dtype('O')

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %%
change_type= lambda x: chipo[x].str.replace("$","").astype(float)
chipo["item_price"]=change_type("item_price")

# %% [markdown]
# #### Step 13.c. Check the item price type

# %%
chipo["item_price"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
chipo["item_price"].sum()
# Out:
# 34500.16

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
chipo["item_price"].mean()
# Out:
# 7.464335785374297

# %%
chipo["item_price"].sum()/chipo["item_price"].count() #2nd way
# Out:
# 7.464335785374297

# %% [markdown]
# ### Step 17. How many different items are sold?

# %%
len(chipo["item_name"].unique())
# Out:
# 50

# %%
chipo["item_name"].nunique()
# Out:
# 50
