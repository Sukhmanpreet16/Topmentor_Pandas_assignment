# %%
import pandas as pd

# %%
cast= pd.read_csv("D:/Data science assignments/Python assignment 4/File/cast.csv")

# %%
cast.head()
# Out:
#                   title    year      name   type                character  \
# 0        Closet Monster  2015.0  Buffy #1  actor                  Buffy 4
# 1       Suuri illusioni  1985.0    Homo $  actor                   Guests
# 2   Battle of the Sexes  2017.0   $hutter  actor          Bobby Riggs Fan
# 3  Secret in Their Eyes  2015.0   $hutter  actor          2002 Dodger Fan
# 4            Steve Jobs  2015.0   $hutter  actor  1988 Opera House Patron
#
#       n
# 0   NaN
# 1  22.0
# 2  10.0
# 3   NaN
# 4   NaN

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
cast["title"].nunique()
# Out:
# 166670

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
df=cast.sort_values(by="year")[["title", "year"]].drop_duplicates().head(2)
df
# Out:
#                          title    year
# 464860              Miss Jerry  1894.0
# 1718214  Soldiers of the Cross  1900.0

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
cast[cast["title"]=="Hamlet"]["title"].count()
# Out:
# 218

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
cast[cast["title"]=="North by Northwest"]["title"].count()
# Out:
# 81

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
cast_sorted=cast.sort_values(by="year")
hamlet_first=cast_sorted[cast_sorted["title"]=="Hamlet"][["title","year"]][0:1]
hamlet_first
# Out:
#           title    year
# 1545289  Hamlet  1910.0

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
treasure_island= cast_sorted[cast_sorted["title"]=="Treasure Island"][["title","year"]]
treasure_island
# Out:
#                    title    year
# 339256   Treasure Island  1918.0
# 840745   Treasure Island  1918.0
# 1473574  Treasure Island  1918.0
# 1715014  Treasure Island  1918.0
# 830114   Treasure Island  1918.0
# ...                  ...     ...
# 1637661  Treasure Island  1999.0
# 1797264  Treasure Island  1999.0
# 1375015  Treasure Island  1999.0
# 1975279  Treasure Island  1999.0
# 114904   Treasure Island  1999.0
#
# [154 rows x 2 columns]

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
cast[cast["year"]==1950]["title"].count()
# Out:
# 14653

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
cast[cast["year"]==1960]["title"].count()
# Out:
# 11551

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
cast[(cast["year"]>=1950) & (cast["year"]<=1959)]["title"].count()
# Out:
# 137408

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
cast[cast["title"]=="Batman"][["title","year"]]
# Out:
#           title    year
# 95672    Batman  1943.0
# 96186    Batman  1943.0
# 114034   Batman  1989.0
# 119476   Batman  1989.0
# 149767   Batman  1989.0
# ...         ...     ...
# 2068050  Batman  1989.0
# 2096318  Batman  1989.0
# 2099960  Batman  1989.0
# 2115809  Batman  1989.0
# 2152546  Batman  1989.0
#
# [89 rows x 2 columns]

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
cast[cast["title"]=="Inception"]["character"].count()
# Out:
# 52

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
cast[(cast["title"]=="Inception") & (cast["n"].isna())]["character"].count()
# Out:
# 21

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
cast[(cast["title"]=="Inception") & (cast["n"].notna())]["character"].count()
# Out:
# 31

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
cast[(cast["title"]=="North by Northwest")& (cast["n"].notna())].sort_values(by="n")
# Out:
#                       title    year               name   type  \
# 840374   North by Northwest  1959.0         Cary Grant  actor
# 1404704  North by Northwest  1959.0        James Mason  actor
# 343701   North by Northwest  1959.0     Leo G. Carroll  actor
# 1634552  North by Northwest  1959.0        Philip Ober  actor
# 1229083  North by Northwest  1959.0      Martin Landau  actor
# 1746383  North by Northwest  1959.0       Edward Platt  actor
# 642085   North by Northwest  1959.0  Robert Ellenstein  actor
# 447893   North by Northwest  1959.0    Philip Coolidge  actor
# 1454363  North by Northwest  1959.0      Patrick McVey  actor
# 198496   North by Northwest  1959.0       Edward Binns  actor
# 1334726  North by Northwest  1959.0          Ken Lynch  actor
#
#                            character     n
# 840374            Roger O. Thornhill   1.0
# 1404704              Phillip Vandamm   3.0
# 343701                 The Professor   5.0
# 1634552              Lester Townsend   7.0
# ...

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
cast[(cast["title"]=="Sleuth") & (cast["year"]==1972)].sort_values(by="n")
# Out:
#           title    year                name   type  \
# 1644328  Sleuth  1972.0    Laurence Olivier  actor
# 314691   Sleuth  1972.0       Michael Caine  actor
# 360365   Sleuth  1972.0      Alec Cawthorne  actor
# 1412647  Sleuth  1972.0  John (II) Matthews  actor
# 1396572  Sleuth  1972.0        Teddy Martin  actor
#
#                           character    n
# 1644328                 Andrew Wyke  1.0
# 314691                  Milo Tindle  2.0
# 360365            Inspector Doppler  3.0
# 1412647  Detective Sergeant Tarrant  4.0
# 1396572      Police Constable Higgs  6.0

# %%
cast[(cast["title"]=="Sleuth") & (cast["year"]==2007)].sort_values(by="n")
# Out:
#           title    year                 name   type          character    n
# 314692   Sleuth  2007.0        Michael Caine  actor             Andrew  1.0
# 1246855  Sleuth  2007.0             Jude Law  actor               Milo  2.0
# 1741124  Sleuth  2007.0        Harold Pinter  actor        Man on T.V.  3.0
# 250297   Sleuth  2007.0      Kenneth Branagh  actor  Other Man on T.V.  NaN
# 360366   Sleuth  2007.0  Alec (II) Cawthorne  actor  Inspector Doppler  NaN

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
cast[(cast["title"]=="Hamlet") & (cast["year"]==1921)]["character"].count()
# Out:
# 5

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
cast[(cast["title"]=="Hamlet") & (cast["year"]==1996)]["character"].count()
# Out:
# 38

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
cast[cast["title"]=="Hamlet"]["character"].count()
# Out:
# 218

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
cast[cast["character"]=="Ophelia"]["name"].count()
# Out:
# 7

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
cast[cast["character"]=="The Dude"]["name"].count()
# Out:
# 16

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
cast[cast["character"]=="The Stranger"]["name"].nunique()
# Out:
# 173

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
cast[cast["name"]=="Sidney Poitier"]["character"].count()
# Out:
# 43

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
cast[cast["name"]=="Judi Dench"]["character"].count()
# Out:
# 0

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
cast[(cast["name"]=="Cary Grant") & (cast["n"]==2)].sort_values(by="year")
# Out:
#                          title    year        name   type  \
# 840364        Madame Butterfly  1932.0  Cary Grant  actor
# 840384      She Done Him Wrong  1933.0  Cary Grant  actor
# 840403       The Woman Accused  1933.0  Cary Grant  actor
# 840395  The Eagle and the Hawk  1933.0  Cary Grant  actor
# 840358            I'm No Angel  1933.0  Cary Grant  actor
# 840404     Thirty Day Princess  1934.0  Cary Grant  actor
# 840339          Born to Be Bad  1934.0  Cary Grant  actor
# 840347           Enter Madame!  1935.0  Cary Grant  actor
# 840414       Wings in the Dark  1935.0  Cary Grant  actor
# 840388         Sylvia Scarlett  1936.0  Cary Grant  actor
# 840412         Wedding Present  1936.0  Cary Grant  actor
# 840413     When You're in Love  1937.0  Cary Grant  actor
# 840392         The Awful Truth  1937.0  Cary Grant  actor
# 840402   The Toast of New York  1937.0  Cary Grant  actor
# 840408                  Topper  1937.0  Cary Grant  actor
# ...

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
cast[(cast["name"]=="Cary Grant") & (cast["n"]==1)].sort_values(by="year")
# Out:
#                                        title    year        name   type  \
# 840355                          Hot Saturday  1932.0  Cary Grant  actor
# 840350                         Gambling Ship  1933.0  Cary Grant  actor
# 840363                  Ladies Should Listen  1934.0  Cary Grant  actor
# 840361                      Kiss and Make-Up  1934.0  Cary Grant  actor
# 840398                      The Last Outpost  1935.0  Cary Grant  actor
# 840391     The Amazing Quest of Ernest Bliss  1936.0  Cary Grant  actor
# 840337                        Big Brown Eyes  1936.0  Cary Grant  actor
# 840379                Only Angels Have Wings  1939.0  Cary Grant  actor
# 840352                             Gunga Din  1939.0  Cary Grant  actor
# 840399                The Philadelphia Story  1940.0  Cary Grant  actor
# 840353                       His Girl Friday  1940.0  Cary Grant  actor
# 840397               The Howards of Virginia  1940.0  Cary Grant  actor
# ...

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
cast[(cast["year"]>=1950) & (cast["year"]<1960) ]["character"].count()
# Out:
# 137408

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
cast[(cast["n"]==1) & (cast["year"]<=1980)]["character"].count()
# Out:
# 38187

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
cast[cast["year"]<=1980]["n"].isna().sum()
# Out:
# 299849
